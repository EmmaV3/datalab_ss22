# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\emmav\\OneDrive\\Dokumente\\DataAnalysisLab22\\datalab_ss22\\solutions'

# %%
os.chdir('C:/Users/emmav/OneDrive/Dokumente/DataAnalysisLab22/datalab_ss22/code')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\emmav\\OneDrive\\Dokumente\\DataAnalysisLab22\\datalab_ss22\\code'

# %%
data1 = np.loadtxt('data1.txt')
data2 = np.loadtxt('data2.txt')
data3 = np.loadtxt('data3.txt')
data4 = np.loadtxt('data4.txt')
data5 = np.loadtxt('data5.txt')
data6 = np.loadtxt('data6.txt')
data7 = np.loadtxt('data7.txt')
data8 = np.loadtxt('data8.txt')
data9 = np.loadtxt('data9.txt')

# %%
X1 = []
X2 = []
X3 = []
X4 = []
X5 = []
X6 = []
X7 = []
X8 = []
X9 = []

# %%
Y1 = []
Y2 = []
Y3 = []
Y4 = []
Y5 = []
Y6 = []
Y7 = []
Y8 = []
Y9 = []

# %%
for i in range(len(data1)):
    for j in range(2):
        if j == 0:
            X1.append(data1[i][j])
        else:
            Y1.append(data1[i][j])

# %%
for i in range(len(data2)):
    for j in range(2):
        if j == 0:
            X2.append(data2[i][j])
        else:
            Y2.append(data2[i][j])

# %%
for i in range(len(data3)):
    for j in range(2):
        if j == 0:
            X3.append(data3[i][j])
        else:
            Y3.append(data3[i][j])

# %%
for i in range(len(data4)):
    for j in range(2):
        if j == 0:
            X4.append(data4[i][j])
        else:
            Y4.append(data4[i][j])

# %%
for i in range(len(data5)):
    for j in range(2):
        if j == 0:
            X5.append(data5[i][j])
        else:
            Y5.append(data5[i][j])

# %%
for i in range(len(data6)):
    for j in range(2):
        if j == 0:
            X6.append(data6[i][j])
        else:
            Y6.append(data6[i][j])

# %%
for i in range(len(data7)):
    for j in range(2):
        if j == 0:
            X7.append(data7[i][j])
        else:
            Y7.append(data7[i][j])

# %%
for i in range(len(data8)):
    for j in range(2):
        if j == 0:
            X8.append(data8[i][j])
        else:
            Y8.append(data8[i][j])

# %%
for i in range(len(data9)):
    for j in range(2):
        if j == 0:
            X9.append(data9[i][j])
        else:
            Y9.append(data9[i][j])

# %%
plt.plot(X1,Y1)
plt.xlim([0,0.5])
plt.show()

# %%
plt.plot(X2,Y2)
plt.show()

# %%
plt.plot(X3,Y3)
plt.show()

# %%
plt.plot(X4,Y4)
plt.show()

# %%
plt.plot(X5,Y5)
plt.show()

# %%
plt.plot(X7,Y7)
plt.show()

# %%
plt.plot(X8,Y8)
plt.show()

# %%
plt.plot(X9,Y9)
plt.show()

# %%
result1 = np.loadtxt('result_data1.txt')
RX1 =[]
RY1 =[]
for i in range(len(result1)):
    RX1.append(result1[i][0])
    RY1.append(result1[i][2])

# %%
plt.plot(RX1,RY1)
plt.xlim([250, 300])
plt.show()

# %%
result1_1 = np.loadtxt('result_data1_1.txt')
RX1_1 =[]
RY1_1 =[]
for i in range(len(result1_1)):
    RX1_1.append(result1_1[i][0])
    RY1_1.append(result1_1[i][2])

# %%
plt.plot(RX1_1,RY1_1)
plt.xlim([250, 300])
plt.show()

# %%
result1_2 = np.loadtxt('result_data1_2.txt')
RX1_2 =[]
RY1_2 =[]
for i in range(len(result1_2)):
    RX1_2.append(result1_2[i][0])
    RY1_2.append(result1_2[i][2])

# %%
plt.plot(RX1_2,RY1_2)
plt.xlim([250, 300])
plt.show()
